# %% [markdown]
# # Predicting the NBA Draft
#
# In this project, the goal is to look at what factors are the most important for NBA draft picks. The end goal of this project is to try and predict the [2021 NBA draft](https://en.wikipedia.org/wiki/2021_NBA_draft) that will take place on July 29th. But to get to that point, we must look to see what are the most important factors for an NBA draft pick. The project will be broken up into 3 sections:
# 1. The data wrangling
# 2. Analysis of important factors
# 3. Machine learning and predictions
#
# Over the course of this guide, we hope the reader is able to understand how and why data analysis is done, and would be able to follow similar steps to do some data science on other topics.

# %% [markdown]
# ## Part 1: Data Wrangling
#
# Perhaps the most important part is to get the data. You can't do any data science without data! For this project, two datasets are needed. First, a collection of past NBA draft picks college stats. This is what we will do analysis on, and train our machine learning model on. This data is ...
#
# Secondly, a dataset is needed for the current NBA draft class. With this data, we can feed that into our model and get predictions of the draft order

# %%
import pandas as pd

# %%
df = pd.read_csv('past_college_players.csv', '\t')
df
# Out:
#                                    RK  PICK                PLAYER Unnamed: 3  \
# 1    25 So 6-7    Reggie Bullock (12)  97.2        North Carolina        ACC
# 2    11 Fr 6-6     Klay Thompson (09)  91.8        Washington St.        P12
# 3    46 Fr 6-2  Andrew Goudelock (08)   0.0  College of Charlesto         SC
# 4    46 Fr 6-3     Norman Powell (12)  89.6                  UCLA        P12
# 5    19 Fr 6-7     Kevin Huerter (17)  87.2              Maryland        B10
# ...                               ...   ...                   ...        ...
# 1298 52 Fr 6-9     Joel Bolomboy (13)   0.0             Weber St.       BSky
# 1299 48 So 7-0    Dakari Johnson (15)  98.2              Kentucky        SEC
# 1300 54 So 6-7    Arsalan Kazemi (11)   0.0                  Rice       CUSA
# 1301 60 Jr 6-8    Dwayne Collins (09)  77.6              Miami FL        ACC
# 1302 30 So 6-7      Jimmy Butler (09)   0.0             Marquette         BE
#
# ...
